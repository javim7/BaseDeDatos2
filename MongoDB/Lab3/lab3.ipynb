# %%
import pymongo
import certifi
import pandas as pd

# %%
client = pymongo.MongoClient("mongodb+srv://admin:1234@cluster0.efqgnct.mongodb.net/lab3?retryWrites=true&w=majority")
db = client['lab3']

# %%
for col in db.list_collections():
    print(col)
# Out:
# {'name': 'wines', 'type': 'collection', 'options': {}, 'info': {'readOnly': False, 'uuid': Binary(b'\x95\xb0\x0f\x88\xfe\xdcE\xb3\xb6\xa3Nv0>;\xd7', 4)}, 'idIndex': {'v': 2, 'key': {'_id': 1}, 'name': '_id_'}}

# %%
df = pd.read_csv('./winemag-data.csv', header=1)
df
# Out:
#              0      US  \
# 0            1   Spain
# 1            2      US
# 2            3      US
# 3            4  France
# 4            5   Spain
# ...        ...     ...
# 150924  150925   Italy
# 150925  150926  France
# 150926  150927   Italy
# 150927  150928  France
# 150928  150929   Italy
#
#        This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.  \
# 0       Ripe aromas of fig, blackberry and cassis are ...
# 1       Mac Watson honors the memory of a wine once ma...
# 2       This spent 20 months in 30% new French oak, an...
# 3       This is the top wine from La Bégude, named aft...
# 4       Deep, dense and pure from the opening bell, th...
# ...

# %%
from pymongo import InsertOne, DeleteMany, ReplaceOne, UpdateOne
bulk = []

for index, row in df.iterrows():
    bulk.append(InsertOne(row.to_dict()))

bulk[:5]
# Out:
# [InsertOne({'0': 1, 'US': 'Spain', 'This tremendous 100% varietal wine hails from Oakville and was aged over three years in oak. Juicy red-cherry fruit and a compelling hint of caramel greet the palate, framed by elegant, fine tannins and a subtle minty tone in the background. Balanced and rewarding from start to finish, it has years ahead of it to develop further nuance. Enjoy 2022–2030.': 'Ripe aromas of fig, blackberry and cassis are softened and sweetened by a slathering of oaky chocolate and vanilla. This is full, layered, intense and cushioned on the palate, with rich flavors of chocolaty black fruits and baking spices. A toasty, everlasting finish is heady but ideally balanced. Drink through 2023.', "Martha's Vineyard": 'Carodorum Selección Especial Reserva', '96': 96, '235.0': 110.0, 'California': 'Northern Spain', 'Napa Valley': 'Toro', 'Napa': nan, 'Cabernet Sauvignon': 'Tinta de Toro', 'Heitz': 'Bodega Carmen Rodríguez'}),
# ...

# %%
# db.wines.bulk_write(bulk)
for i in range(0, len(bulk), 1000):
    db.wines.bulk_write(bulk[i:i+1000])
